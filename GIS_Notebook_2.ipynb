# %%
import pandas as pd

df = pd.read_csv('data_combined_large.csv')
df.head()
# Out:
#   District      Date  U component  V component  Precipitation  Evaporation  \
# 0  Belgaum  1/1/2013     0.426855    -0.320713   2.493960e-04    -0.001394
# 1  Belgaum  1/2/2013     0.673685    -0.432207   2.390000e-05    -0.001310
# 2  Belgaum  1/3/2013     0.952910    -0.701152   1.210000e-05    -0.001242
# 3  Belgaum  1/4/2013     1.269262    -0.965036   8.590000e-07    -0.001194
# 4  Belgaum  1/5/2013     1.250703    -0.562236   1.280000e-06    -0.001274
#
#    Rainfall  Solar_Radiation  Temperature_2m  Temperature_2m_max  \
# 0  0.000063      13705660.82       25.460176           30.279121
# 1  0.000061      14710954.80       25.998532           31.641468
# 2  0.000060      14711322.23       26.021237           31.800086
# 3  0.000059      14603959.20       25.224446           31.736162
# 4  0.000058      16906569.45       24.505082           32.057580
#
#    Temperature_2m_min Day Length  Elevation
# 0           20.755110   11:14:41        735
# 1           20.256431   11:14:55        735
# 2           20.238681   11:15:10        735
# 3           19.086185   11:15:27        735
# 4           17.713013   11:15:43        735

# %%
population_density = {
    'Bellary': 348.667069,
    'Bijapur': 248.354600,
    'Dakshin Kannad': 508.252631,
    'Dharwad': 484.360639,
    'Mysore': 539.209810,
    'Raichur': 254.841457,
    'Shimoga': 196.675173,
    'Bagalkot': 312.305028,
    'Chamrajnagar': 196.120686,
    'Chitradurga': 214.884400,
    'Davanagere': 364.326028,
    'Gadag': 258.759199,
    'Haveri': 325.622265,
    'Koppal': 280.843844,
    'Udupi': 332.865582,
    'Belgaum': 403.317823,
    'Bidar': 333.993620,
    'Chikmagalur': 167.052884,
    'Gulbarga': 265.359527,
    'Hassan': 269.281724,
    'Kodagu': 153.404346,
    'Kolar': 361.393506,
    'Mandya': 354.713881,
    'Tumkur': 265.105494,
    'Bangalore Rural': 546.505180,
    'Bangalore Urban': 5731.121745,
    'Uttar Kannand': 162.184809
}

slope_data = {
    'Belgaum': 45.0259757018606,
    'Bellary': 67.42181164463624,
    'Bidar': 56.064149861014194,
    'Bijapur': 22.606478133784393,
    'Chikmagalur': 89.80723235107253,
    'Dakshin Kannad': 89.96650251078262,
    'Dharwad': 89.86522216547199,
    'Gulbarga': 67.42636495544444,
    'Hassan': 22.391635818729696,
    'Kodagu': 67.45031643668311,
    'Kolar': 67.42883696576287,
    'Mandya': 89.89242339644969,
    'Mysore': 0.0035750831406478056,
    'Raichur': 44.77406350249045,
    'Shimoga': 22.552286342885836,
    'Tumkur': 89.96992788857911,
    'Uttar Kannand': 44.9851714095228,
    'Bagalkot': 33.6588237295,
    'Bangalore Rural': 0.022098718896955916,
    'Bangalore Urban': 89.95356408120647,
    'Chamrajnagar': 22.488324650034947,
    'Chitradurga': 89.951097782121,
    'Davanagere': 89.9449093635449,
    'Gadag': 67.34616638925156,
    'Haveri': 44.885029018905705,
    'Koppal': 78.63907954791058,
    'Udupi': 67.40869172724405
}
highway_distance_data = {
    'Belgaum': 2742.6315518090823,
    'Bellary': 15836.502469506911,
    'Bidar': 10935.40665119477,
    'Bijapur': 20000,  
    'Chikmagalur': 8370.725204510138,
    'Dakshin Kannad': 1344.4907113598229,
    'Dharwad': 2094.277559746804,
    'Gulbarga': 8728.509976550835,
    'Hassan': 1551.9045317685432,
    'Kodagu': 12514.086381185836,
    'Kolar': 846.7154693422773,
    'Mandya': 11720.7864968229,
    'Mysore': 657.0832034942507,
    'Raichur': 20000,  
    'Shimoga': 11152.111374865352,
    'Tumkur': 6789.653388182513,
    'Uttar Kannand': 12183.229239399087,
    'Bagalkot': 3833.670053877414,
    'Bangalore Rural': 529.2436927157444,
    'Bangalore Urban': 184.984489873634,
    'Chamrajnagar': 20000,  
    'Chitradurga': 8097.970973718581,
    'Davanagere': 8861.907570157726,
    'Gadag': 3393.2403454242153,
    'Haveri': 4099.924590179761,
    'Koppal': 20000,  
    'Udupi': 5745.117967132812
}
land_use_data = {
    'Belgaum': 1.056359,
    'Bellary': 0.881657,
    'Bidar': 0.468981,
    'Bijapur': 0.559861,
    'Chikmagalur': 1.890443,
    'Dakshin Kannad': 1.979869,
    'Dharwad': 0.553759,
    'Gulbarga': 0.395389,
    'Hassan': 1.434566,
    'Kodagu': 2.083377,
    'Kolar': 0.944723,
    'Mandya': 1.790405,
    'Mysore': 1.333417,
    'Raichur': 0.442940,
    'Shimoga': 1.782672,
    'Tumkur': 1.306495,
    'Uttar Kannand': 1.918026,
    'Bagalkot': 0.886607,
    'Bangalore Rural': 1.554554,
    'Bangalore Urban': 1.123392,
    'Chamrajnagar': 1.945911,
    'Chitradurga': 1.197356,
    'Davanagere': 0.976373,
    'Gadag': 0.605982,
    'Haveri': 0.558529,
    'Koppal': 0.540095,
    'Udupi': 1.996717
}

# %%
df['population_density'] = df['District'].map(population_density)

# %%
df['slope']=df['District'].map(slope_data)
df['highways']=df['District'].map(highway_distance_data)
df['LULC']=df['District'].map(land_use_data)
df
# Out:
#        District        Date  U component  V component  Precipitation  \
# 0       Belgaum    1/1/2013     0.426855    -0.320713   2.493960e-04
# 1       Belgaum    1/2/2013     0.673685    -0.432207   2.390000e-05
# 2       Belgaum    1/3/2013     0.952910    -0.701152   1.210000e-05
# 3       Belgaum    1/4/2013     1.269262    -0.965036   8.590000e-07
# 4       Belgaum    1/5/2013     1.250703    -0.562236   1.280000e-06
# ...         ...         ...          ...          ...            ...
# 108454    Udupi  12/27/2023    -1.623763    -0.851944   8.520000e-07
# 108455    Udupi  12/28/2023    -0.665053    -0.521992   0.000000e+00
# 108456    Udupi  12/29/2023    -0.412568    -0.291093   8.520000e-07
# 108457    Udupi  12/30/2023    -0.091583    -0.605784   0.000000e+00
# 108458    Udupi  12/31/2023    -0.419537     0.083167   1.670000e-06
#
#         Evaporation  Rainfall  Solar_Radiation  Temperature_2m  \
# 0         -0.001394  0.000063      13705660.82       25.460176
# 1         -0.001310  0.000061      14710954.80       25.998532
# 2         -0.001242  0.000060      14711322.23       26.021237
# 3         -0.001194  0.000059      14603959.20       25.224446
# 4         -0.001274  0.000058      16906569.45       24.505082
# ...             ...       ...              ...             ...
# 108454    -0.002600  0.000553      18292538.85       26.504629
# 108455    -0.002381  0.000535      17746188.27       26.219945
# 108456    -0.002273  0.000517      17281781.83       26.737814
# 108457    -0.002286  0.000500      17644872.29       27.114642
# 108458    -0.002171  0.000484      17713029.70       26.753689
#
#         Temperature_2m_max  Temperature_2m_min Day Length  Elevation  \
# 0                30.279121           20.755110   11:14:41        735
# 1                31.641468           20.256431   11:14:55        735
# 2                31.800086           20.238681   11:15:10        735
# 3                31.736162           19.086185   11:15:27        735
# 4                32.057580           17.713013   11:15:43        735
# ...                    ...                 ...        ...        ...
# 108454           34.569003           19.809253   11:22:17         46
# 108455           33.830411           20.152091   11:22:24         46
# 108456           33.990279           20.522006   11:22:30         46
# 108457           33.982552           21.929603   11:22:39         46
# 108458           34.034959           21.693736   11:22:47         46
#
#         population_density      slope     highways      LULC
# 0               403.317823  45.025976  2742.631552  1.056359
# 1               403.317823  45.025976  2742.631552  1.056359
# 2               403.317823  45.025976  2742.631552  1.056359
# 3               403.317823  45.025976  2742.631552  1.056359
# 4               403.317823  45.025976  2742.631552  1.056359
# ...                    ...        ...          ...       ...
# 108454          332.865582  67.408692  5745.117967  1.996717
# 108455          332.865582  67.408692  5745.117967  1.996717
# 108456          332.865582  67.408692  5745.117967  1.996717
# 108457          332.865582  67.408692  5745.117967  1.996717
# 108458          332.865582  67.408692  5745.117967  1.996717
#
# [108459 rows x 17 columns]

# %%
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# District              0
# Date                  0
# U component           0
# V component           0
# Precipitation         0
# Evaporation           0
# Rainfall              0
# Solar_Radiation       0
# Temperature_2m        0
# Temperature_2m_max    0
# Temperature_2m_min    0
# Day Length            0
# Elevation             0
# population_density    0
# slope                 0
# highways              0
# LULC                  0
# dtype: int64

# %%
df['District'].unique()
# Out:
# array(['Belgaum', 'Bellary', 'Bidar', 'Bijapur', 'Chikmagalur',
#        'Dakshin Kannad', 'Dharwad', 'Gulbarga', 'Hassan', 'Kodagu',
#        'Kolar', 'Mandya', 'Mysore', 'Raichur', 'Shimoga', 'Tumkur',
#        'Uttar Kannand', 'Bagalkot', 'Bangalore Rural', 'Bangalore Urban',
#        'Chamrajnagar', 'Chitradurga', 'Davanagere', 'Gadag', 'Haveri',
#        'Koppal', 'Udupi'], dtype=object)

# %%
data_types = df.dtypes
print(data_types)
# Out:
# District               object
# Date                   object
# U component           float64
# V component           float64
# Precipitation         float64
# Evaporation           float64
# Rainfall              float64
# Solar_Radiation       float64
# Temperature_2m        float64
# Temperature_2m_max    float64
# Temperature_2m_min    float64
# Day Length             object
# Elevation               int64
# population_density    float64
# slope                 float64
# highways              float64
# LULC                  float64
# dtype: object

# %% [markdown]
# #### City

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['city_encoded'] = label_encoder.fit_transform(df['District'])

# %%
df
# Out:
#        District        Date  U component  V component  Precipitation  \
# 0       Belgaum    1/1/2013     0.426855    -0.320713   2.493960e-04
# 1       Belgaum    1/2/2013     0.673685    -0.432207   2.390000e-05
# 2       Belgaum    1/3/2013     0.952910    -0.701152   1.210000e-05
# 3       Belgaum    1/4/2013     1.269262    -0.965036   8.590000e-07
# 4       Belgaum    1/5/2013     1.250703    -0.562236   1.280000e-06
# ...         ...         ...          ...          ...            ...
# 108454    Udupi  12/27/2023    -1.623763    -0.851944   8.520000e-07
# 108455    Udupi  12/28/2023    -0.665053    -0.521992   0.000000e+00
# 108456    Udupi  12/29/2023    -0.412568    -0.291093   8.520000e-07
# 108457    Udupi  12/30/2023    -0.091583    -0.605784   0.000000e+00
# 108458    Udupi  12/31/2023    -0.419537     0.083167   1.670000e-06
#
#         Evaporation  Rainfall  Solar_Radiation  Temperature_2m  \
# 0         -0.001394  0.000063      13705660.82       25.460176
# 1         -0.001310  0.000061      14710954.80       25.998532
# 2         -0.001242  0.000060      14711322.23       26.021237
# 3         -0.001194  0.000059      14603959.20       25.224446
# 4         -0.001274  0.000058      16906569.45       24.505082
# ...             ...       ...              ...             ...
# 108454    -0.002600  0.000553      18292538.85       26.504629
# 108455    -0.002381  0.000535      17746188.27       26.219945
# 108456    -0.002273  0.000517      17281781.83       26.737814
# 108457    -0.002286  0.000500      17644872.29       27.114642
# 108458    -0.002171  0.000484      17713029.70       26.753689
#
#         Temperature_2m_max  Temperature_2m_min Day Length  Elevation  \
# 0                30.279121           20.755110   11:14:41        735
# 1                31.641468           20.256431   11:14:55        735
# 2                31.800086           20.238681   11:15:10        735
# 3                31.736162           19.086185   11:15:27        735
# 4                32.057580           17.713013   11:15:43        735
# ...                    ...                 ...        ...        ...
# 108454           34.569003           19.809253   11:22:17         46
# 108455           33.830411           20.152091   11:22:24         46
# 108456           33.990279           20.522006   11:22:30         46
# 108457           33.982552           21.929603   11:22:39         46
# 108458           34.034959           21.693736   11:22:47         46
#
#         population_density      slope     highways      LULC  city_encoded
# 0               403.317823  45.025976  2742.631552  1.056359             3
# 1               403.317823  45.025976  2742.631552  1.056359             3
# 2               403.317823  45.025976  2742.631552  1.056359             3
# 3               403.317823  45.025976  2742.631552  1.056359             3
# 4               403.317823  45.025976  2742.631552  1.056359             3
# ...                    ...        ...          ...       ...           ...
# 108454          332.865582  67.408692  5745.117967  1.996717            25
# 108455          332.865582  67.408692  5745.117967  1.996717            25
# 108456          332.865582  67.408692  5745.117967  1.996717            25
# 108457          332.865582  67.408692  5745.117967  1.996717            25
# 108458          332.865582  67.408692  5745.117967  1.996717            25
#
# [108459 rows x 18 columns]

# %% [markdown]
# ## Date

# %%
df['time'] = pd.to_datetime(df['Date'])

df['year'] = df['time'].dt.year
df['month'] = df['time'].dt.month
df['day'] = df['time'].dt.day

# %%
df['Day Length']=df['Day Length'].apply(
    lambda x: sum(int(unit) * factor for unit, factor in zip(x.split(':'), [60, 1, 1/60]))
).astype(int)

# %%
df
# Out:
#        District        Date  U component  V component  Precipitation  \
# 0       Belgaum    1/1/2013     0.426855    -0.320713   2.493960e-04
# 1       Belgaum    1/2/2013     0.673685    -0.432207   2.390000e-05
# 2       Belgaum    1/3/2013     0.952910    -0.701152   1.210000e-05
# 3       Belgaum    1/4/2013     1.269262    -0.965036   8.590000e-07
# 4       Belgaum    1/5/2013     1.250703    -0.562236   1.280000e-06
# ...         ...         ...          ...          ...            ...
# 108454    Udupi  12/27/2023    -1.623763    -0.851944   8.520000e-07
# 108455    Udupi  12/28/2023    -0.665053    -0.521992   0.000000e+00
# 108456    Udupi  12/29/2023    -0.412568    -0.291093   8.520000e-07
# 108457    Udupi  12/30/2023    -0.091583    -0.605784   0.000000e+00
# 108458    Udupi  12/31/2023    -0.419537     0.083167   1.670000e-06
#
#         Evaporation  Rainfall  Solar_Radiation  Temperature_2m  \
# 0         -0.001394  0.000063      13705660.82       25.460176
# 1         -0.001310  0.000061      14710954.80       25.998532
# 2         -0.001242  0.000060      14711322.23       26.021237
# 3         -0.001194  0.000059      14603959.20       25.224446
# 4         -0.001274  0.000058      16906569.45       24.505082
# ...             ...       ...              ...             ...
# 108454    -0.002600  0.000553      18292538.85       26.504629
# 108455    -0.002381  0.000535      17746188.27       26.219945
# 108456    -0.002273  0.000517      17281781.83       26.737814
# 108457    -0.002286  0.000500      17644872.29       27.114642
# 108458    -0.002171  0.000484      17713029.70       26.753689
#
#         Temperature_2m_max  ...  Elevation  population_density      slope  \
# 0                30.279121  ...        735          403.317823  45.025976
# 1                31.641468  ...        735          403.317823  45.025976
# 2                31.800086  ...        735          403.317823  45.025976
# 3                31.736162  ...        735          403.317823  45.025976
# 4                32.057580  ...        735          403.317823  45.025976
# ...                    ...  ...        ...                 ...        ...
# 108454           34.569003  ...         46          332.865582  67.408692
# 108455           33.830411  ...         46          332.865582  67.408692
# 108456           33.990279  ...         46          332.865582  67.408692
# 108457           33.982552  ...         46          332.865582  67.408692
# 108458           34.034959  ...         46          332.865582  67.408692
#
#            highways      LULC  city_encoded       time  year month  day
# 0       2742.631552  1.056359             3 2013-01-01  2013     1    1
# 1       2742.631552  1.056359             3 2013-01-02  2013     1    2
# 2       2742.631552  1.056359             3 2013-01-03  2013     1    3
# 3       2742.631552  1.056359             3 2013-01-04  2013     1    4
# 4       2742.631552  1.056359             3 2013-01-05  2013     1    5
# ...             ...       ...           ...        ...   ...   ...  ...
# 108454  5745.117967  1.996717            25 2023-12-27  2023    12   27
# 108455  5745.117967  1.996717            25 2023-12-28  2023    12   28
# 108456  5745.117967  1.996717            25 2023-12-29  2023    12   29
# 108457  5745.117967  1.996717            25 2023-12-30  2023    12   30
# 108458  5745.117967  1.996717            25 2023-12-31  2023    12   31
#
# [108459 rows x 22 columns]

# %% [markdown]
# ## Time
# Time appears to be in UTC therefore added 5 hours and 30 minutes to each value

# %%
data_types = df.dtypes
print(data_types)
# Out:
# District                      object
# Date                          object
# U component                  float64
# V component                  float64
# Precipitation                float64
# Evaporation                  float64
# Rainfall                     float64
# Solar_Radiation              float64
# Temperature_2m               float64
# Temperature_2m_max           float64
# Temperature_2m_min           float64
# Day Length                     int64
# Elevation                      int64
# population_density           float64
# slope                        float64
# highways                     float64
# LULC                         float64
# city_encoded                   int64
# time                  datetime64[ns]
# year                           int64
# month                          int64
# day                            int64
# dtype: object

# %% [markdown]
# ## Dimensionality Reduction

# %% [markdown]
# ## calculating total sunlight time

# %%
import math
import numpy
df['windspeed_10m']=numpy.sqrt(df['U component']**2+df['V component']**2)
df['Rainfall']=df['Rainfall']*1e3

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# /tmp/ipykernel_40255/3213337034.py:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
columns=['Rainfall', 'Temperature_2m', 'windspeed_10m', 'Elevation', 'Temperature_2m', 'Solar_Radiation', 'Rainfall', 'Evaporation', 'Day Length','population_density','slope','highways','LULC']

avg = df.groupby('District')[columns].mean().reset_index()

# %%
avg.dtypes
# Out:
# District               object
# Rainfall              float64
# Temperature_2m        float64
# windspeed_10m         float64
# Elevation             float64
# Temperature_2m        float64
# Solar_Radiation       float64
# Rainfall              float64
# Evaporation           float64
# Day Length            float64
# population_density    float64
# slope                 float64
# highways              float64
# LULC                  float64
# dtype: object

# %%
# List all features (columns) in the DataFrame
features = df.columns.tolist()
print(features)
# Out:
# ['District', 'Date', 'U component', 'V component', 'Precipitation', 'Evaporation', 'Rainfall', 'Solar_Radiation', 'Temperature_2m', 'Temperature_2m_max', 'Temperature_2m_min', 'Day Length', 'Elevation', 'population_density', 'slope', 'highways', 'LULC', 'city_encoded', 'time', 'year', 'month', 'day', 'windspeed_10m']

# %% [markdown]
# ## Finidings
# Each city has unique longitude and latitude values, i.e. only one location per city is given as an entry, our decision is now to select the best city using AHP

# %%
alternatives = ['Belgaum', 'Bellary', 'Bidar', 'Bijapur', 'Chikmagalur',
       'Dakshin Kannad', 'Dharwad', 'Gulbarga', 'Hassan', 'Kodagu',
       'Kolar', 'Mandya', 'Mysore', 'Raichur', 'Shimoga', 'Tumkur',
       'Uttar Kannand', 'Bagalkot', 'Bangalore Rural', 'Bangalore Urban',
       'Chamrajnagar', 'Chitradurga', 'Davanagere', 'Gadag', 'Haveri',
       'Koppal', 'Udupi']

criteria = ['District', 'Date', 'U component', 'V component', 'Precipitation', 'Evaporation', 'Rainfall', 'Solar_Radiation', 'Temperature_2m', 'Temperature_2m_max', 'Temperature_2m_min', 'Day Length', 'Elevation', 'population_density', 'slope', 'highways', 'LULC', 'city_encoded', 'time', 'year', 'month', 'day', 'windspeed_10m']

# %%
# !pip install ahpy

# %%
import ahpy

# %% [markdown]
# #Feature Selection

# %%
windCriteria = ['windspeed_10m','LULC','slope','highways']

solarCriteria = ['Temperature_2m',
                'Solar_Radiation',  'windspeed_10m',
                'Evaporation','LULC','highways']

# %%
import itertools
windPairs = list(itertools.combinations(windCriteria, 2))
print(windPairs)
nWP=len(windPairs)
print(nWP)

solarPairs = list(itertools.combinations(solarCriteria, 2))
print(solarPairs)
nSP = len(solarPairs)
print(nSP)
# Out:
# [('windspeed_10m', 'LULC'), ('windspeed_10m', 'slope'), ('windspeed_10m', 'highways'), ('LULC', 'slope'), ('LULC', 'highways'), ('slope', 'highways')]
# 6
# [('Temperature_2m', 'Solar_Radiation'), ('Temperature_2m', 'windspeed_10m'), ('Temperature_2m', 'Evaporation'), ('Temperature_2m', 'LULC'), ('Temperature_2m', 'highways'), ('Solar_Radiation', 'windspeed_10m'), ('Solar_Radiation', 'Evaporation'), ('Solar_Radiation', 'LULC'), ('Solar_Radiation', 'highways'), ('windspeed_10m', 'Evaporation'), ('windspeed_10m', 'LULC'), ('windspeed_10m', 'highways'), ('Evaporation', 'LULC'), ('Evaporation', 'highways'), ('LULC', 'highways')]
# 15

# %% [markdown]
# ### Function to calculate wind values

# %%
# lept
print("Need the following number of values;")
print(nWP)

import random

def generate_random_array(size, min_value, max_value):
    if size <= 0 or max_value <= min_value:
        raise ValueError("Invalid input parameters")

    random_array = [random.randint(min_value, max_value) for _ in range(size)]
    return random_array

error = 10
while error > 0.1 :
  windParameters = generate_random_array(nWP, 1, 9)

  windComparison = dict(zip(windPairs, windParameters))
  wind  = ahpy.Compare(name='Wind', comparisons=windComparison, precision=3, random_index='saaty')
  error = wind.consistency_ratio
  if error < 0.1:
    finalWindValues = windParameters
    break;

finalWindValues=[1,4,6,1/4,2,2]
print("final wind values :",finalWindValues)
# Out:
# Need the following number of values;
# 6
# final wind values : [1, 4, 6, 0.25, 2, 2]

# %%
finalWindValues=[1,4,6,1/4,2,2]

# %% [markdown]
# ### Setting importance values for wind

# %%
windValues = finalWindValues
windComparison = dict(zip(windPairs, windValues))
print(windComparison)
# Out:
# {('windspeed_10m', 'LULC'): 1, ('windspeed_10m', 'slope'): 4, ('windspeed_10m', 'highways'): 6, ('LULC', 'slope'): 0.25, ('LULC', 'highways'): 2, ('slope', 'highways'): 2}

# %%
wind  = ahpy.Compare(name='Wind', comparisons=windComparison, precision=3, random_index='saaty')

print(wind.target_weights)

weightsWind = wind.target_weights

print(wind.consistency_ratio)
# Out:
# {'windspeed_10m': 0.465, 'slope': 0.27, 'LULC': 0.184, 'highways': 0.081}
# 0.01599999999999996

# %% [markdown]
# ###Function to calculate solar values

# %%
# lept
# [('Temperature_2m', 'Solar_Radiation'), ('Temperature_2m', 'windspeed_10m'),
#  ('Temperature_2m', 'Evaporation'), ('Temperature_2m', 'LULC'), ('Temperature_2m', 'highways'),
#  ('Solar_Radiation', 'windspeed_10m'), ('Solar_Radiation', 'Evaporation'), ('Solar_Radiation', 'LULC'), 
#  ('Solar_Radiation', 'highways'), ('windspeed_10m', 'Evaporation'), ('windspeed_10m', 'LULC'), 
#  ('windspeed_10m', 'highways'), ('Evaporation', 'LULC'), ('Evaporation', 'highways'), ('LULC', 'highways')]
print("Need the following number of values;")
print(nSP)

error = 10
while error > 0.1 :
  solarParameters = generate_random_array(nSP, 1, 9)

  solarComparison = dict(zip(solarPairs, solarParameters))
  solar  = ahpy.Compare(name='Solar', comparisons=solarComparison, precision=3, random_index='saaty')
  error = solar.consistency_ratio
  if error < 0.1:
    finalSolarValues = solarParameters
    break;
    
finalSolarValues=[1/2,4,3,4,2,6,7,7,5,1/2,2,1/2,1/2,1/2,1/6]

print("final solar values :",finalSolarValues)
# Out:
# Need the following number of values;
# 15
# final solar values : [0.5, 4, 3, 4, 2, 6, 7, 7, 5, 0.5, 2, 0.5, 0.5, 0.5, 0.16666666666666666]

# %% [markdown]
# ### Setting importance values for solar

# %%
solarValues = finalSolarValues
solarComparison = dict(zip(solarPairs, solarValues))
print(solarComparison)
# Out:
# {('Temperature_2m', 'Solar_Radiation'): 0.5, ('Temperature_2m', 'windspeed_10m'): 4, ('Temperature_2m', 'Evaporation'): 3, ('Temperature_2m', 'LULC'): 4, ('Temperature_2m', 'highways'): 2, ('Solar_Radiation', 'windspeed_10m'): 6, ('Solar_Radiation', 'Evaporation'): 7, ('Solar_Radiation', 'LULC'): 7, ('Solar_Radiation', 'highways'): 5, ('windspeed_10m', 'Evaporation'): 0.5, ('windspeed_10m', 'LULC'): 2, ('windspeed_10m', 'highways'): 0.5, ('Evaporation', 'LULC'): 0.5, ('Evaporation', 'highways'): 0.5, ('LULC', 'highways'): 0.16666666666666666}

# %%
{('Temperature_2m', 'Solar_Radiation'): 0.5, ('Temperature_2m', 'windspeed_10m'): 4, ('Temperature_2m', 'Evaporation'): 3, ('Temperature_2m', 'LULC'): 4, ('Temperature_2m', 'highways'): 2, ('Solar_Radiation', 'windspeed_10m'): 6, ('Solar_Radiation', 'Evaporation'): 7, ('Solar_Radiation', 'LULC'): 7, ('Solar_Radiation', 'highways'): 5, ('windspeed_10m', 'Evaporation'): 0.5, ('windspeed_10m', 'LULC'): 2, ('windspeed_10m', 'highways'): 0.5, ('Evaporation', 'LULC'): 0.5, ('Evaporation', 'highways'): 0.5, ('LULC', 'highways'): 0.16666666666666666}0
# Out:
# {('Temperature_2m', 'Solar_Radiation'): 0.5,
#  ('Temperature_2m', 'windspeed_10m'): 4,
#  ('Temperature_2m', 'Evaporation'): 3,
#  ('Temperature_2m', 'LULC'): 4,
#  ('Temperature_2m', 'highways'): 2,
#  ('Solar_Radiation', 'windspeed_10m'): 6,
#  ('Solar_Radiation', 'Evaporation'): 7,
#  ('Solar_Radiation', 'LULC'): 7,
#  ('Solar_Radiation', 'highways'): 5,
#  ('windspeed_10m', 'Evaporation'): 0.5,
#  ('windspeed_10m', 'LULC'): 2,
#  ('windspeed_10m', 'highways'): 0.5,
#  ('Evaporation', 'LULC'): 0.5,
#  ('Evaporation', 'highways'): 0.5,
#  ('LULC', 'highways'): 0.16666666666666666}

# %%
solar  = ahpy.Compare(name='Solar', comparisons=solarComparison, precision=3, random_index='saaty')

print(solar.target_weights)

weightsSolar = solar.target_weights

print(solar.consistency_ratio)
# Out:
# {'Solar_Radiation': 0.445, 'Temperature_2m': 0.22, 'highways': 0.147, 'Evaporation': 0.067, 'windspeed_10m': 0.064, 'LULC': 0.057}
# 0.073

# %% [markdown]
# # Calculating Suitablility_index

# %% [markdown]
# ### All the parameters considered

# %%
# Combine keys of the two dictionaries into a single array
combined_keys = list(weightsWind.keys()) + list(weightsSolar.keys())

print(combined_keys)
# Out:
# ['windspeed_10m', 'slope', 'LULC', 'highways', 'Solar_Radiation', 'Temperature_2m', 'highways', 'Evaporation', 'windspeed_10m', 'LULC']

# %% [markdown]
# ['windspeed_10m_max', 'winddirection_10m_dominant', 'elevation', 'rain_sum', 'temperature_2m_mean', 'temperature_2m_mean', 'shortwave_radiation_sum', 'precipitation_hours', 'sun_time', 'et0_fao_evapotranspiration']

# %% [markdown]
# ## windspeed_10m

# %%
import pandas as pd
from itertools import combinations


# Extract city names and corresponding temperature values
city_names
ag'), ('Bangalore Rural', 'Gulbarga'), ('Bangalore Rural', 'Hassan'), ('Bangalore Rural', 'Haveri'), ('Bangalore Rural', 'Kodagu'), ('Bangalore Rural', 'Kolar'), ('Bangalore Rural', 'Koppal'), ('Bangalore Rural', 'Mandya'), ('Bangalore Rural', 'Mysore'), ('Bangalore Rural', 'Raichur'), ('Bangalore Rural', 'Shimoga'), ('Bangalore Rural', 'Tumkur'), ('Bangalore Rural', 'Udupi'), ('Bangalore Rural', 'Uttar Kannand'), ('Bangalore Urban', 'Belgaum'), ('Bangalore Urban', 'Bellary'), ('Bangalore Urban', 'Bidar'), ('Bangalore Urban', 'Bijapur'), ('Bangalore Urban', 'Chamrajnagar'), ('Bangalore Urban', 'Chikmagalur'), ('Bangalore Urban', 'Chitradurga'), ('Bangalore Urban', 'Dakshin Kannad'), ('Bangalore Urban', 'Davanagere'), ('Bangalore Urban', 'Dharwad'), ('Bangalore Urban', 'Gadag'), ('Bangalore Urban', 'Gulbarga'), ('Bangalore Urban', 'Hassan'), ('Bangalore Urban', 'Haveri'), ('Bangalore Urban', 'Kodagu'), ('Bangalore Urban', 'Kolar'), ('Bangalore Urban', 'Koppal'), ('Bangalore Urban', 'Mandya'), ('Bangalore Urban', 'Mysore'), ('Bangalore Urban', 'Raichur'), ('Bangalore Urban', 'Shimoga'), ('Bangalore Urban', 'Tumkur'), ('Bangalore Urban', 'Udupi'), ('Bangalore Urban', 'Uttar Kannand'), ('Belgaum', 'Bellary'), ('Belgaum', 'Bidar'), ('Belgaum', 'Bijapur'), ('Belgaum', 'Chamrajnagar'), ('Belgaum', 'Chikmagalur'), ('Belgaum', 'Chitradurga'), ('Belgaum', 'Dakshin Kannad'), ('Belgaum', 'Davanagere'), ('Belgaum', 'Dharwad'), ('Belgaum', 'Gadag'), ('Belgaum', 'Gulbarga'), ('Belgaum', 'Hassan'), ('Belgaum', 'Haveri'), ('Belgaum', 'Kodagu'), ('Belgaum', 'Kolar'), ('Belgaum', 'Koppal'), ('Belgaum', 'Mandya'), ('Belgaum', 'Mysore'), ('Belgaum', 'Raichur'), ('Belgaum', 'Shimoga'), ('Belgaum', 'Tumkur'), ('Belgaum', 'Udupi'), ('Belgaum', 'Uttar Kannand'), ('Bellary', 'Bidar'), ('Bellary', 'Bijapur'), ('Bellary', 'Chamrajnagar'), ('Bellary', 'Chikmagalur'), ('Bellary', 'Chitradurga'), ('Bellary', 'Dakshin Kannad'), ('Bellary', 'Davanagere'), ('Bellary', 'Dharwad'), ('Bellary', 'Gadag'), ('Bellary', 'Gulbarga'), ('Bellary', 'Hassan'), ('Bellary', 'Haveri'), ('Bellary', 'Kodagu'), ('Bellary', 'Kolar'), ('Bellary', 'Koppal'), ('Bellary', 'Mandya'), ('Bellary', 'Mysore'), ('Bellary', 'Raichur'), ('Bellary', 'Shimoga'), ('Bellary', 'Tumkur'), ('Bellary', 'Udupi'), ('Bellary', 'Uttar Kannand'), ('Bidar', 'Bijapur'), ('Bidar', 'Chamrajnagar'), ('Bidar', 'Chikmagalur'), ('Bidar', 'Chitradurga'), ('Bidar', 'Dakshin Kannad'), ('Bidar', 'Davanagere'), ('Bidar', 'Dharwad'), ('Bidar', 'Gadag'), ('Bidar', 'Gulbarga'), ('Bidar', 'Hassan'), ('Bidar', 'Haveri'), ('Bidar', 'Kodagu'), ('Bidar', 'Kolar'), ('Bidar', 'Koppal'), ('Bidar', 'Mandya'), ('Bidar', 'Mysore'), ('Bidar', 'Raichur'), ('Bidar', 'Shimoga'), ('Bidar', 'Tumkur'), ('Bidar', 'Udupi'), ('Bidar', 'Uttar Kannand'), ('Bijapur', 'Chamrajnagar'), ('Bijapur', 'Chikmagalur'), ('Bijapur', 'Chitradurga'), ('Bijapur', 'Dakshin Kannad'), ('Bijap ...
# 351
# {'Dakshin Kannad': 0.095, 'Udupi': 0.07, 'Kodagu': 0.064, 'Chikmagalur': 0.049, 'Uttar Kannand': 0.047, 'Chamrajnagar': 0.046, 'Shimoga': 0.04, 'Hassan': 0.038, 'Mysore': 0.038, 'Bidar': 0.034, 'Mandya': 0.034, 'Bangalore Rural': 0.032, 'Tumkur': 0.032, 'Belgaum': 0.03, 'Gulbarga': 0.03, 'Bangalore Urban': 0.029, 'Kolar': 0.029, 'Chitradurga': 0.028, 'Davanagere': 0.028, 'Dharwad': 0.028, 'Haveri': 0.028, 'Raichur': 0.028, 'Bagalkot': 0.026, 'Bellary': 0.026, 'Gadag': 0.025, 'Koppal': 0.025, 'Bijapur': 0.022}
# 0.0

# %% [markdown]
# ## Slope

# %%
# Extract city names and corresponding slope values
city_names = avg['District']
temperature_values = avg['slope']

# Initialize an empty matrix to store comparisons
matrix_size = len(city_names)
comparison_matrix = [[0] * matrix_size for _ in range(matrix_size)]

# Fill the matrix with pairwise comparisons
for i, j in combinations(range(matrix_size), 2):
    comparison_matrix[i][j] = temperature_values[j] / temperature_values[i]
    comparison_matrix[j][i] = 1 / comparison_matrix[i][j]

for i in range(matrix_size):
    comparison_matrix[i][i] = 1

# Flatten the upper triangular part of the matrix (excluding diagonal)
flattened_upper_triangular = [
    comparison_matrix[i][j] for i in range(len(comparison_matrix)) for j in range(i + 1, len(comparison_matrix[i]))
]

wind_city_Pairs = list(combinations(city_names, 2))
wind_slope_max = dict(zip(wind_city_Pairs, flattened_upper_triangular))

slope_max = ahpy.Compare(name='slope_max', comparisons=wind_slope_max, precision=3, random_index='dd')

print(slope_max.target_weights)
print(slope_max.consistency_ratio)
# Out:
# {'Mysore': 0.859, 'Bangalore Rural': 0.139, 'Bagalkot': 0.0, 'Bangalore Urban': 0.0, 'Belgaum': 0.0, 'Bellary': 0.0, 'Bidar': 0.0, 'Bijapur': 0.0, 'Chamrajnagar': 0.0, 'Chikmagalur': 0.0, 'Chitradurga': 0.0, 'Dakshin Kannad': 0.0, 'Davanagere': 0.0, 'Dharwad': 0.0, 'Gadag': 0.0, 'Gulbarga': 0.0, 'Hassan': 0.0, 'Haveri': 0.0, 'Kodagu': 0.0, 'Kolar': 0.0, 'Koppal': 0.0, 'Mandya': 0.0, 'Raichur': 0.0, 'Shimoga': 0.0, 'Tumkur': 0.0, 'Udupi': 0.0, 'Uttar Kannand': 0.0}
# 0.0

# %% [markdown]
# ## Land use pattern

# %%
city_names = avg['District']
temperature_values = avg['LULC']

matrix_size = len(city_names)
comparison_matrix = [[0] * matrix_size for _ in range(matrix_size)]

for i, j in combinations(range(matrix_size), 2):
    comparison_matrix[i][j] = temperature_values[j] / temperature_values[i]
    comparison_matrix[j][i] = 1 / comparison_matrix[i][j]

for i in range(matrix_size):
    comparison_matrix[i][i] = 1

# Flatten the upper triangular part of the matrix (excluding diagonal)
flattened_upper_triangular = [
    comparison_matrix[i][j] for i in range(len(comparison_matrix)) for j in range(i + 1, len(comparison_matrix[i]))
]

wind_city_Pairs = list(combinations(city_names, 2))
wind_LULC_max = dict(zip(wind_city_Pairs, flattened_upper_triangular))

LULC_max = ahpy.Compare(name='LULC_max', comparisons=wind_LULC_max, precision=3, random_index='dd')

print(LULC_max.target_weights)
print(LULC_max.consistency_ratio)
# Out:
# {'Gulbarga': 0.085, 'Raichur': 0.076, 'Bidar': 0.071, 'Koppal': 0.062, 'Dharwad': 0.061, 'Bijapur': 0.06, 'Haveri': 0.06, 'Gadag': 0.055, 'Bagalkot': 0.038, 'Bellary': 0.038, 'Kolar': 0.035, 'Davanagere': 0.034, 'Belgaum': 0.032, 'Bangalore Urban': 0.03, 'Chitradurga': 0.028, 'Tumkur': 0.026, 'Mysore': 0.025, 'Hassan': 0.023, 'Bangalore Rural': 0.022, 'Mandya': 0.019, 'Shimoga': 0.019, 'Chikmagalur': 0.018, 'Chamrajnagar': 0.017, 'Dakshin Kannad': 0.017, 'Udupi': 0.017, 'Uttar Kannand': 0.017, 'Kodagu': 0.016}
# 0.0

# %%
avg=avg.loc[:,~avg.columns.duplicated()]

# %%
avg
# Out:
#            District  Rainfall  Temperature_2m  windspeed_10m  Elevation  \
# 0          Bagalkot  0.278589       26.084684       3.041440      519.0
# 1   Bangalore Rural  0.320454       23.797761       2.393444      788.0
# 2   Bangalore Urban  0.338856       23.259454       2.672933      921.0
# 3           Belgaum  0.877831       24.855914       2.591932      735.0
# 4           Bellary  0.130055       25.984922       3.019202      589.0
# 5             Bidar  0.550645       25.873798       2.282604      570.0
# 6           Bijapur  0.391180       26.784283       3.591358      581.0
# 7      Chamrajnagar  0.291457       23.677108       1.687457      690.0
# 8       Chikmagalur  2.634534       22.862675       1.578510      884.0
# 9       Chitradurga  0.185998       24.985072       2.757126      666.0
# 10   Dakshin Kannad  5.992350       25.499694       0.821741       52.0
# 11       Davanagere  0.324859       24.737843       2.780981      587.0
# 12          Dharwad  0.491268       24.710375       2.769748      639.0
# 13            Gadag  0.294467       25.308335       3.087498      657.0
# 14         Gulbarga  0.424909       26.793654       2.599347      397.0
# 15           Hassan  1.170181       22.645565       2.071274      956.0
# 16           Haveri  0.368914       24.782394       2.787215      579.0
# 17           Kodagu  4.238147       22.334827       1.215923      890.0
# 18            Kolar  0.213852       23.815161       2.705024      948.0
# 19           Koppal  0.190747       25.916377       3.111796      620.0
# 20           Mandya  0.245521       24.121686       2.303169      734.0
# 21           Mysore  0.547294       23.444227       2.034466      737.0
# 22          Raichur  0.234982       27.037149       2.786316      415.0
# 23          Shimoga  2.824307       24.076272       1.953312      624.0
# 24           Tumkur  0.267122       24.307317       2.396309      792.0
# 25            Udupi  6.764866       25.895462       1.116774       46.0
# 26    Uttar Kannand  3.557919       24.806323       1.640323      188.0
#
#     Temperature_2m  Solar_Radiation  Rainfall  Evaporation  Day Length  \
# 0        26.084684     1.586448e+07  0.278589    -0.002006  730.030122
# 1        23.797761     1.544454e+07  0.320454    -0.002555  729.694548
rix_size = len(city_names)
comparison_matrix = [[0] * matrix_size for _ in range(matrix_size)]

for i, j in combinations(range(matrix_size), 2):
    comparison_matrix[i][j] = temperature_values[j] / temperature_values[i]
    comparison_matrix[j][i] = 1 / comparison_matrix[i][j]

for i in range(matrix_size):
    comparison_matrix[i][i] = 1

# Flatten the upper triangular part of the matrix (excluding diagonal)
flattened_upper_triangular = [
    comparison_matrix[i][j] for i in range(len(comparison_matrix)) for j in range(i + 1, len(comparison_matrix[i]))
]

wind_city_Pairs = list(combinations(city_names, 2))
wind_highways_max = dict(zip(wind_city_Pairs, flattened_upper_triangular))

highways_max = ahpy.Compare(name='highways_max', comparisons=wind_highways_max, precision=3, random_index='dd')

print(highways_max.target_weights)
print(highways_max.consistency_ratio)
# Out:
# {'Bangalore Urban': 0.373, 'Bangalore Rural': 0.13, 'Mysore': 0.105, 'Kolar': 0.081, 'Dakshin Kannad': 0.051, 'Hassan': 0.044, 'Dharwad': 0.033, 'Belgaum': 0.025, 'Gadag': 0.02, 'Bagalkot': 0.018, 'Haveri': 0.017, 'Udupi': 0.012, 'Tumkur': 0.01, 'Chitradurga': 0.009, 'Chikmagalur': 0.008, 'Davanagere': 0.008, 'Gulbarga': 0.008, 'Bidar': 0.006, 'Kodagu': 0.006, 'Mandya': 0.006, 'Shimoga': 0.006, 'Uttar Kannand': 0.006, 'Bellary': 0.004, 'Bijapur': 0.003, 'Chamrajnagar': 0.003, 'Koppal': 0.003, 'Raichur': 0.003}
# 0.0

# %% [markdown]
# ## temperature_2m_mean

# %%
city_names = avg['District']
temperature_values = avg['Temperature_2m']

matrix_size = len(city_names)
comparison_matrix = [[0] * matrix_size for _ in range(matrix_size)]

for i, j in combinations(range(matrix_size), 2):
    comparison_matrix[i][j] = temperature_values[j] / temperature_values[i]
    comparison_matrix[j][i] = 1/comparison_matrix[i][j]

for i in range(matrix_size):
  comparison_matrix[i][i] = 1
  
# Flatten the upper triangular part of the matrix (excluding diagonal)
flattened_upper_triangular = [comparison_matrix[i][j] for i in range(len(comparison_matrix)) for j in range(i + 1, len(comparison_matrix[i]))]

print(flattened_upper_triangular)
print(len(flattened_upper_triangular))

wind_city_Pairs = list(itertools.combinations(city_names, 2))
print(wind_city_Pairs)
len_temperature_2m_mean=len(wind_city_Pairs)
print(len_temperature_2m_mean)

wind_temperature_2m_mean = dict(zip(wind_city_Pairs, flattened_upper_triangular))

temperature_2m_mean  = ahpy.Compare(name='temperature_2m_mean', comparisons=wind_temperature_2m_mean, precision=3, random_index='dd')

print(temperature_2m_mean.target_weights)

weightstemperature_2m_mean = temperature_2m_mean.target_weights

print(temperature_2m_mean.consistency_ratio)
# Out:
# [0.9123269827394109, 0.8916900962398292, 0.9528930668904416, 0.9961754730479158, 0.9919153365362148, 1.0268203068469912, 0.9077015445112584, 0.8764789242391265, 0.9578445680673466, 0.977573439915912, 0.9483666082764814, 0.9473135854894066, 0.9702373760602828, 1.0271795637667176, 0.8681556171651348, 0.9500745336433913, 0.8562429854133254, 0.9129940640447467, 0.9935476785875114, 0.9247452159743299, 0.8987736711277853, 1.0365143724921813, 0.9230041661012203, 0.9318616884515479, 0.9927458684986322, 0.9509919213649024, 0.9773799450306554, 1.0444644134378491, 1.0919061826459808, 1.0872366545137433, 1.1254959310353785, 0.9949300652993252, 0.9607070061737681, 1.0498917451627503, 1.0715165268713065, 1.0395029701180774, 1.0383487536945828, 1.0634754801913087, 1.125889711912765, 0.9515838439397633, 1.041375024106639, 0.9385264292439491, 1.000731186644653, 1.089025861763095, 1.0136116035915448, 0.9851442389975908, 1.1361215793266108, 1.0117032418900396, 1.0214119565481674, 1.0881469991359352, 1.0423805711734992, 1.068637042071791, 1.1171767828853223, 1.1123991852315347, 1.151543917754602, 1.017956292594196, 0
# [('Bagalkot', 'Bangalore Rural'), ('Bagalkot', 'Bangalore Urban'), ('Bagalkot', 'Belgaum'), ('Bagalkot', 'Bellary'), ('Bagalkot', 'Bidar'), ('Bagalkot', 'Bijapur'), ('Bagalkot', 'Chamrajnagar'), ('Bagalkot', 'Chikmagalur'), ('Bagalkot', 'Chitradurga'), ('Bagalkot', 'Dakshin Kannad'), ('Bagalkot', 'Davanagere'), ('Bagalkot', 'Dharwad'), ('Bagalkot', 'Gadag'), ('Bagalkot', 'Gulbarga'), ('Bagalkot', 'Hassan'), ('Bagalkot', 'Haveri'), ('Bagalkot', 'Kodagu'), ('Bagalkot', 'Kolar'), ('Bagalkot', 'Koppal'), ('Bagalkot', 'Mandya'), ('Bagalkot', 'Mysore'), ('Bagalkot', 'Raichur'), ('Bagalkot', 'Shimoga'), ('Bagalkot', 'Tumkur'), ('Bagalkot', 'Udupi'), ('Bagalkot', 'Uttar Kannand'), ('Bangalore Rural', 'Bangalore Urban'), ('Bangalore Rural', 'Belgaum'), ('Bangalore Rural', 'Bellary'), ('Bangalore Rural', 'Bidar'), ('Bangalore Rural', 'Bijapur'), ('Bangalore Rural', 'Chamrajnagar'), ('Bangalore Rural', 'Chikmagalur'), ('Bangalore Rural', 'Chitradurga'), ('Bangalore Rural', 'Dakshin Kannad'), ('Bangalore Rural', 'Davanagere'), ('Bangalore Rural', 'Dharwad'), ('Bangalore Rural', 'Gadag'), ('Bangalore Rural', 'Gulbarga'), ('Bangalore Rural', 'Hassan'), ('Bangalore Rural', 'Haveri'), ('Bangalore Rural', 'Kodagu'), ('Bangalore Rural', 'Kolar'), ('Bangalore Rural', 'Koppal'), ('Bangalore Rural', 'Mandya'), ('Bangalore Rural', 'Mysore'), ('Bangalore Rural', 'Raichur'), ('Bangalore Rural', 'Shimoga'), ('Bangalore Rural', 'Tumkur'), ('Bangalore Rural', 'Udupi'), ('Bangalore Rural', 'Uttar Kannand'), ('Bangalore Urban', 'Belgaum'), ('Bangalore Urban', 'Bellary'), ('Bangalore Urban', 'Bidar'), ('Bangalore Urban', 'Bijapur'), ('Bangalore Urban', 'Chamrajnagar'), ('Bangalore Urban', 'Chikmagalur'), ('Bangalore Urban', 'Chitradurga'), ('Bangalore Urban', 'Dakshin Kannad'), ('Bangalore Urban', 'Davanagere'), ('Bangalore Urban', 'Dharwad'), ('Bangalore Urban', 'Gadag'), ('Bangalore Urban', 'Gulbarga'), ('Bangalore Urban', 'Hassan'), ('Bangalore Urban', 'Haveri'), ('Bangalore Urban', 'Kodagu'), ('Bangalore Urban', 'Kolar'), ('Bangalore Urban', 'Koppal'), ('Bangalore Urban', 'Mandya'), ('Bangalore Urban', 'Mysore'), ('Bangalore Urban', 'Raichur'), ('Bangalore Urban', 'Shimoga'), ('Bangalore Urban', 'Tumkur'), ('Bangalore Urban', 'Udupi'), ('Bangalore Urban', 'Uttar Kannand'), ('Belgaum', 'Bellary'), ('Belgaum', 'Bidar'), ('Belgaum', 'Bijapur'), ('Belgaum', 'Chamrajnagar'), ('Belgaum', 'Chikmagalur'), ('Belgaum', 'Chitradurga'), ('Belgaum', 'Dakshin Kannad'), ('Belgaum', 'Davanagere'), ('Belgaum', 'Dharwad'), ('Belgaum', 'Gadag'), ('Belgaum', 'Gulbarga'), ('Belgaum', 'Hassan'), ('Belgaum', 'Haveri'), ('Belgaum', 'Kodagu'), ('Belgaum', 'Kolar'), ('Belgaum', 'Koppal'), ('Belgaum', 'Mandya'), ('Belgaum', 'Mysore'), ('Belgaum', 'Raichur'), ('Belgaum', 'Shimoga'), ('Belgaum', 'Tumkur'), ('Belgaum', 'Udupi'), ('Belgaum', 'Uttar Kannand'), ('Bellary', 'Bidar'), ('Bellary', 'Bijapur'), ('Bellary', 'Chamrajnagar'), ('Bellary', 'Chikmagalur'), ('Bellary', 'Chitradurga'), ('Bellary', 'Dakshin Kannad'), ('Bellary', 'Davanagere'), ('Bellary', 'Dharwad'), ('Bellary', 'Gadag'), ('Bellary', 'Gulbarga'), ('Bellary', 'Hassan'), ('Bellary', 'Haveri'), ('Bellary', 'Kodagu'), ('Bellary', 'Kolar'), ('Bellary', 'Koppal'), ('Bellary', 'Mandya'), ('Bellary', 'Mysore'), ('Bellary', 'Raichur'), ('Bellary', 'Shimoga'), ('Bellary', 'Tumkur'), ('Bellary', 'Udupi'), ('Bellary', 'Uttar Kannand'), ('Bidar', 'Bijapur'), ('Bidar', 'Chamrajnagar'), ('Bidar', 'Chikmagalur'), ('Bidar', 'Chitradurga'), ('Bidar', 'Dakshin Kannad'), ('Bidar', 'Davanagere'), ('Bidar', 'Dharwad'), ('Bidar', 'Gadag'), ('Bidar', 'Gulbarga'), ('Bidar', 'Hassan'), ('Bidar', 'Haveri'), ('Bidar', 'Kodagu'), ('Bidar', 'Kolar'), ('Bidar', 'Koppal'), ('Bidar', 'Mandya'), ('Bidar', 'Mysore'), ('Bidar', 'Raichur'), ('Bidar', 'Shimoga'), ('Bidar', 'Tumkur'), ('Bidar', 'Udupi'), ('Bidar', 'Uttar Kannand'), ('Bijapur', 'Chamrajnagar'), ('Bijapur', 'Chikmagalur'), ('Bijapur', 'Chitradurga'), ('Bijapur', 'Dakshin Kannad'), ('Bijap ...
# 351
# {'Kodagu': 0.041, 'Chikmagalur': 0.04, 'Hassan': 0.04, 'Bangalore Urban': 0.039, 'Chamrajnagar': 0.039, 'Mysore': 0.039, 'Bangalore Rural': 0.038, 'Kolar': 0.038, 'Mandya': 0.038, 'Shimoga': 0.038, 'Tumkur': 0.038, 'Belgaum': 0.037, 'Chitradurga': 0.037, 'Davanagere': 0.037, 'Dharwad': 0.037, 'Haveri': 0.037, 'Uttar Kannand': 0.037, 'Dakshin Kannad': 0.036, 'Gadag': 0.036, 'Bagalkot': 0.035, 'Bellary': 0.035, 'Bidar': 0.035, 'Koppal': 0.035, 'Udupi': 0.035, 'Bijapur': 0.034, 'Gulbarga': 0.034, 'Raichur': 0.034}
# 0.0

# %% [markdown]
# ## shortwave_radiation_sum

# %%
city_names = avg['District']
temperature_values = avg['Solar_Radiation']

matrix_size = len(city_names)
comparison_matrix = [[0] * matrix_size for _ in range(matrix_size)]

for i, j in combinations(range(matrix_size), 2):
    if temperature_values[i] == 0 or temperature_values[j] == 0:
        comparison_matrix[i][j] = 1
        comparison_matrix[j][i] = 0.1
    else:
        comparison_matrix[i][j] = temperature_values[j] / temperature_values[i]
        comparison_matrix[j][i] = 1/comparison_matrix[i][j]

for i in range(matrix_size):
  comparison_matrix[i][i] = 1

# Flatten the upper triangular part of the matrix (excluding diagonal)
flattened_upper_triangular = [comparison_matrix[i][j] for i in range(len(comparison_matrix)) for j in range(i + 1, len(comparison_matrix[i]))]

print(flattened_upper_triangular)
print(len(flattened_upper_triangular))

wind_city_Pairs = list(itertools.combinations(city_names, 2))
print(wind_city_Pairs
Bangalore Rural', 'Shimoga'), ('Bangalore Rural', 'Tumkur'), ('Bangalore Rural', 'Udupi'), ('Bangalore Rural', 'Uttar Kannand'), ('Bangalore Urban', 'Belgaum'), ('Bangalore Urban', 'Bellary'), ('Bangalore Urban', 'Bidar'), ('Bangalore Urban', 'Bijapur'), ('Bangalore Urban', 'Chamrajnagar'), ('Bangalore Urban', 'Chikmagalur'), ('Bangalore Urban', 'Chitradurga'), ('Bangalore Urban', 'Dakshin Kannad'), ('Bangalore Urban', 'Davanagere'), ('Bangalore Urban', 'Dharwad'), ('Bangalore Urban', 'Gadag'), ('Bangalore Urban', 'Gulbarga'), ('Bangalore Urban', 'Hassan'), ('Bangalore Urban', 'Haveri'), ('Bangalore Urban', 'Kodagu'), ('Bangalore Urban', 'Kolar'), ('Bangalore Urban', 'Koppal'), ('Bangalore Urban', 'Mandya'), ('Bangalore Urban', 'Mysore'), ('Bangalore Urban', 'Raichur'), ('Bangalore Urban', 'Shimoga'), ('Bangalore Urban', 'Tumkur'), ('Bangalore Urban', 'Udupi'), ('Bangalore Urban', 'Uttar Kannand'), ('Belgaum', 'Bellary'), ('Belgaum', 'Bidar'), ('Belgaum', 'Bijapur'), ('Belgaum', 'Chamrajnagar'), ('Belgaum', 'Chikmagalur'), ('Belgaum', 'Chitradurga'), ('Belgaum', 'Dakshin Kannad'), ('Belgaum', 'Davanagere'), ('Belgaum', 'Dharwad'), ('Belgaum', 'Gadag'), ('Belgaum', 'Gulbarga'), ('Belgaum', 'Hassan'), ('Belgaum', 'Haveri'), ('Belgaum', 'Kodagu'), ('Belgaum', 'Kolar'), ('Belgaum', 'Koppal'), ('Belgaum', 'Mandya'), ('Belgaum', 'Mysore'), ('Belgaum', 'Raichur'), ('Belgaum', 'Shimoga'), ('Belgaum', 'Tumkur'), ('Belgaum', 'Udupi'), ('Belgaum', 'Uttar Kannand'), ('Bellary', 'Bidar'), ('Bellary', 'Bijapur'), ('Bellary', 'Chamrajnagar'), ('Bellary', 'Chikmagalur'), ('Bellary', 'Chitradurga'), ('Bellary', 'Dakshin Kannad'), ('Bellary', 'Davanagere'), ('Bellary', 'Dharwad'), ('Bellary', 'Gadag'), ('Bellary', 'Gulbarga'), ('Bellary', 'Hassan'), ('Bellary', 'Haveri'), ('Bellary', 'Kodagu'), ('Bellary', 'Kolar'), ('Bellary', 'Koppal'), ('Bellary', 'Mandya'), ('Bellary', 'Mysore'), ('Bellary', 'Raichur'), ('Bellary', 'Shimoga'), ('Bellary', 'Tumkur'), ('Bellary', 'Udupi'), ('Bellary', 'Uttar Kannand'), ('Bidar', 'Bijapur'), ('Bidar', 'Chamrajnagar'), ('Bidar', 'Chikmagalur'), ('Bidar', 'Chitradurga'), ('Bidar', 'Dakshin Kannad'), ('Bidar', 'Davanagere'), ('Bidar', 'Dharwad'), ('Bidar', 'Gadag'), ('Bidar', 'Gulbarga'), ('Bidar', 'Hassan'), ('Bidar', 'Haveri'), ('Bidar', 'Kodagu'), ('Bidar', 'Kolar'), ('Bidar', 'Koppal'), ('Bidar', 'Mandya'), ('Bidar', 'Mysore'), ('Bidar', 'Raichur'), ('Bidar', 'Shimoga'), ('Bidar', 'Tumkur'), ('Bidar', 'Udupi'), ('Bidar', 'Uttar Kannand'), ('Bijapur', 'Chamrajnagar'), ('Bijapur', 'Chikmagalur'), ('Bijapur', 'Chitradurga'), ('Bijapur', 'Dakshin Kannad'), ('Bijap ...
# 351
# {'Dakshin Kannad': 0.039, 'Chikmagalur': 0.038, 'Kodagu': 0.038, 'Udupi': 0.038, 'Uttar Kannand': 0.038, 'Bangalore Rural': 0.037, 'Bangalore Urban': 0.037, 'Bellary': 0.037, 'Chitradurga': 0.037, 'Davanagere': 0.037, 'Dharwad': 0.037, 'Hassan': 0.037, 'Haveri': 0.037, 'Kolar': 0.037, 'Koppal': 0.037, 'Mandya': 0.037, 'Mysore': 0.037, 'Raichur': 0.037, 'Shimoga': 0.037, 'Tumkur': 0.037, 'Bagalkot': 0.036, 'Belgaum': 0.036, 'Bidar': 0.036, 'Chamrajnagar': 0.036, 'Gadag': 0.036, 'Gulbarga': 0.036, 'Bijapur': 0.035}
# 0.0

# %% [markdown]
# ## Evaporation

# %%
# Extract city names and corresponding temperature values
city_names = avg['District']
temperature_values = avg['Evaporation']

# Initialize an empty matrix to store comparisons
matrix_size = len(city_names)
comparison_matrix = [[0] * matrix_size for _ in range(matrix_size)]

# Fill the matrix with pairwise comparisons
for i, j in combinations(range(matrix_size), 2):
    # check if either value is 0 to avoid division by 0
    if temperature_values[i] == 0 or temperature_values[j] == 0:
        comparison_matrix[i][j] = 1
        comparison_matrix[j][i] = 0.1
    else:
        comparison_matrix[i][j] = temperature_values[j] / temperature_values[i]
        comparison_matrix[j][i] = 1/comparison_matrix[i][j]

for i in range(matrix_size):
  comparison_matrix[i][i] = 1

# Print the comparison matrix
# for row in comparison_matrix:
#   print(row)

# Flatten the upper triangular part of the matrix (excluding diagonal)
flattened_upper_triangular = [comparison_matrix[i][j] for i in range(len(comparison_matrix)) for j in range(i + 1, len(comparison_matrix[i]))]

print(flattened_upper_triangular)
print(len(flattened_upper_triangular))

wind_city_Pairs = list(itertools.combinations(city_names, 2))
print(wind_city_Pairs)
len_et0_fao_evapotranspiration=len(wind_city_Pairs)
print(len_et0_fao_evapotranspiration)

wind_et0_fao_evapotranspiration = dict(zip(wind_city_Pairs, flattened_upper_triangular))

et0_fao_evapotranspiration  = ahpy.Compare(name='et0_fao_evapotranspiration', comparisons=wind_et0_fao_evapotranspiration, precision=3, random_index='dd')

print(et0_fao_evapotranspiration.target_weights)

weightset0_fao_evapotranspiration = et0_fao_evapotranspiration.target_weights

print(et0_fao_evapotranspiration.consistency_ratio)
# Out:
# [1.2736916889292567, 1.2686991548713293, 1.069877153216671, 1.0023110372732316, 1.1021894919597208, 0.9469348267082879, 1.2326446951452443, 1.3150138645971945, 1.0660346560049294, 1.4491464787958972, 1.1214706012838098, 1.0779485237763282, 1.0176427517422064, 1.0498111983259535, 1.314468061004925, 1.1183350981881266, 1.5262195945417856, 1.1283052183241487, 0.9925233540661502, 1.2585805948094013, 1.3072310638444935, 0.9993182843385411, 1.2799554658978112, 1.184500392694478, 1.3877995627986477, 1.2932855041443223, 0.9960802648699669, 0.8399812627466193, 0.7869337972330147, 0.8653503053680823, 0.7434568623937081, 0.9677732106279826, 1.0324428399958203, 0.8369644438059446, 1.1377529518263079, 0.8804882775254558, 0.8463182520116135, 0.7989710230406696, 0.8242270931425244, 1.032014319030336, 0.878026533350679, 1.1982645469130913, 0.8858542676624289, 0.7792492976856324, 0.9881359874990168, 1.0263324124721518, 0.7845841289728674, 1.004917812546787, 0.9299741868381364, 1.0895883005763485, 1.0153834836054694, 0.8432867233407887, 0.7900305075673242, 0.8687555972018473, 0.7463824840368286, 0.9715815529728624, 1.03650566767388, 0.840258032735149, 1.1422301916350441, 0.8839531397004426
# [('Bagalkot', 'Bangalore Rural'), ('Bagalkot', 'Bangalore Urban'), ('Bagalkot', 'Belgaum'), ('Bagalkot', 'Bellary'), ('Bagalkot', 'Bidar'), ('Bagalkot', 'Bijapur'), ('Bagalkot', 'Chamrajnagar'), ('Bagalkot', 'Chikmagalur'), ('Bagalkot', 'Chitradurga'), ('Bagalkot', 'Dakshin Kannad'), ('Bagalkot', 'Davanagere'), ('Bagalkot', 'Dharwad'), ('Bagalkot', 'Gadag'), ('Bagalkot', 'Gulbarga'), ('Bagalkot', 'Hassan'), ('Bagalkot', 'Haveri'), ('Bagalkot', 'Kodagu'), ('Bagalkot', 'Kolar'), ('Bagalkot', 'Koppal'), ('Bagalkot', 'Mandya'), ('Bagalkot', 'Mysore'), ('Bagalkot', 'Raichur'), ('Bagalkot', 'Shimoga'), ('Bagalkot', 'Tumkur'), ('Bagalkot', 'Udupi'), ('Bagalkot', 'Uttar Kannand'), ('Bangalore Rural', 'Bangalore Urban'), ('Bangalore Rural', 'Belgaum'), ('Bangalore Rural', 'Bellary'), ('Bangalore Rural', 'Bidar'), ('Bangalore Rural', 'Bijapur'), ('Bangalore Rural', 'Chamrajnagar'), ('Bangalore Rural', 'Chikmagalur'), ('Bangalore Rural', 'Chitradurga'), ('Bangalore Rural', 'Dakshin Kannad'), ('Bangalore Rural', 'Davanagere'), ('Bangalore Rural', 'Dharwad'), ('Bangalore Rural', 'Gadag'), ('Bangalore Rural', 'Gulbarga'), ('Bangalore Rural', 'Hassan'), ('Bangalore Rural', 'Haveri'), ('Bangalore Rural', 'Kodagu'), ('Bangalore Rural', 'Kolar'), ('Bangalore Rural', 'Koppal'), ('Bangalore Rural', 'Mandya'), ('Bangalore Rural', 'Mysore'), ('Bangalore Rural', 'Raichur'), ('Bangalore Rural', 'Shimoga'), ('Bangalore Rural', 'Tumkur'), ('Bangalore Rural', 'Udupi'), ('Bangalore Rural', 'Uttar Kannand'), ('Bangalore Urban', 'Belgaum'), ('Bangalore Urban', 'Bellary'), ('Bangalore Urban', 'Bidar'), ('Bangalore Urban', 'Bijapur'), ('Bangalore Urban', 'Chamrajnagar'), ('Bangalore Urban', 'Chikmagalur'), ('Bangalore Urban', 'Chitradurga'), ('Bangalore Urban', 'Dakshin Kannad'), ('Bangalore Urban', 'Davanagere'), ('Bangalore Urban', 'Dharwad'), ('Bangalore Urban', 'Gadag'), ('Bangalore Urban', 'Gulbarga'), ('Bangalore Urban', 'Hassan'), ('Bangalore Urban', 'Haveri'), ('Bangalore Urban', 'Kodagu'), ('Bangalore Urban', 'Kolar'), ('Bangalore Urban', 'Koppal'), ('Bangalore Urban', 'Mandya'), ('Bangalore Urban', 'Mysore'), ('Bangalore Urban', 'Raichur'), ('Bangalore Urban', 'Shimoga'), ('Bangalore Urban', 'Tumkur'), ('Bangalore Urban', 'Udupi'), ('Bangalore Urban', 'Uttar Kannand'), ('Belgaum', 'Bellary'), ('Belgaum', 'Bidar'), ('Belgaum', 'Bijapur'), ('Belgaum', 'Chamrajnagar'), ('Belgaum', 'Chikmagalur'), ('Belgaum', 'Chitradurga'), ('Belgaum', 'Dakshin Kannad'), ('Belgaum', 'Davanagere'), ('Belgaum', 'Dharwad'), ('Belgaum', 'Gadag'), ('Belgaum', 'Gulbarga'), ('Belgaum', 'Hassan'), ('Belgaum', 'Haveri'), ('Belgaum', 'Kodagu'), ('Belgaum', 'Kolar'), ('Belgaum', 'Koppal'), ('Belgaum', 'Mandya'), ('Belgaum', 'Mysore'), ('Belgaum', 'Raichur'), ('Belgaum', 'Shimoga'), ('Belgaum', 'Tumkur'), ('Belgaum', 'Udupi'), ('Belgaum', 'Uttar Kannand'), ('Bellary', 'Bidar'), ('Bellary', 'Bijapur'), ('Bellary', 'Chamrajnagar'), ('Bellary', 'Chikmagalur'), ('Bellary', 'Chitradurga'), ('Bellary', 'Dakshin Kannad'), ('Bellary', 'Davanagere'), ('Bellary', 'Dharwad'), ('Bellary', 'Gadag'), ('Bellary', 'Gulbarga'), ('Bellary', 'Hassan'), ('Bellary', 'Haveri'), ('Bellary', 'Kodagu'), ('Bellary', 'Kolar'), ('Bellary', 'Koppal'), ('Bellary', 'Mandya'), ('Bellary', 'Mysore'), ('Bellary', 'Raichur'), ('Bellary', 'Shimoga'), ('Bellary', 'Tumkur'), ('Bellary', 'Udupi'), ('Bellary', 'Uttar Kannand'), ('Bidar', 'Bijapur'), ('Bidar', 'Chamrajnagar'), ('Bidar', 'Chikmagalur'), ('Bidar', 'Chitradurga'), ('Bidar', 'Dakshin Kannad'), ('Bidar', 'Davanagere'), ('Bidar', 'Dharwad'), ('Bidar', 'Gadag'), ('Bidar', 'Gulbarga'), ('Bidar', 'Hassan'), ('Bidar', 'Haveri'), ('Bidar', 'Kodagu'), ('Bidar', 'Kolar'), ('Bidar', 'Koppal'), ('Bidar', 'Mandya'), ('Bidar', 'Mysore'), ('Bidar', 'Raichur'), ('Bidar', 'Shimoga'), ('Bidar', 'Tumkur'), ('Bidar', 'Udupi'), ('Bidar', 'Uttar Kannand'), ('Bijapur', 'Chamrajnagar'), ('Bijapur', 'Chikmagalur'), ('Bijapur', 'Chitradurga'), ('Bijapur', 'Dakshin Kannad'), ('Bijap ...
# 351
# {'Bijapur': 0.045, 'Bagalkot': 0.043, 'Bellary': 0.043, 'Koppal': 0.043, 'Raichur': 0.043, 'Gadag': 0.042, 'Gulbarga': 0.041, 'Belgaum': 0.04, 'Chitradurga': 0.04, 'Dharwad': 0.04, 'Bidar': 0.039, 'Davanagere': 0.038, 'Haveri': 0.038, 'Kolar': 0.038, 'Tumkur': 0.036, 'Chamrajnagar': 0.035, 'Bangalore Rural': 0.034, 'Bangalore Urban': 0.034, 'Mandya': 0.034, 'Shimoga': 0.034, 'Chikmagalur': 0.033, 'Hassan': 0.033, 'Mysore': 0.033, 'Uttar Kannand': 0.033, 'Udupi': 0.031, 'Dakshin Kannad': 0.03, 'Kodagu': 0.028}
# 0.0

# %% [markdown]
# # Calculating AHP ranking

# %% [markdown]
# ## WIND

# %%
# Initialize a dictionary to store the weighted sums
weighted_sums = {}

# Iterate through each city name
for city in city_names:
    weighted_sum = (
        weightswindspeed_10m_max[city]*weightsWind ['windspeed_10m'] +slope_max.target_weights[city]*weightsWind['slope']+
        highways_max.target_weights[city]*weightsWind['highways']+LULC_max.target_weights[city]*weightsWind['LULC']
    )
    weighted_sums[city] = weighted_sum


WindRanking = pd.DataFrame(list(weighted_sums.items()), columns=['City', 'Value'])

# Sort the DataFrame by 'roi' in descending order
sorted_avg_wind = WindRanking.sort_values(by='Value', ascending=False)

# Print the sorted DataFrame
# print(sorted_avg_wind)
sorted_avg_wind
# Out:
#     Unnamed: 0             City     Value
# 0           21            Gadag  0.262705
# 1            1  Bangalore Rural  0.066988
# 2           10   Dakshin Kannad  0.051434
# 3            2          Belgaum  0.049218
# 4           25            Udupi  0.036650
# 5           17           Kodagu  0.033190
# 6           14         Gulbarga  0.030238
# 7            5            Bidar  0.029360
# 8           22          Raichur  0.027247
# 9           12          Dharwad  0.026917
# 10           8      Chikmagalur  0.026745
# 11          18            Kolar  0.026486
# 12          26    Uttar Kannand  0.025469
# 13          15           Hassan  0.025466
# 14          16           Haveri  0.025437
# 15           7     Chamrajnagar  0.024761
# 16          13           Mysore  0.023365
# 17          19           Koppal  0.023276
# 18          23          Shimoga  0.022582
# 19           3  Bangalore Urban  0.021863
# 20           6          Bijapur  0.021513
# 21           0         Bagalkot  0.020540
# 22          24           Tumkur  0.020474
# 23          11       Davanagere  0.019924
# 24          20           Mandya  0.019792
# 25           4          Bellary  0.019406
# 26           9      Chitradurga  0.018901

# %% [markdown]
# ## SOLAR

# %%
# Initialize a dictionary to store the weighted sums
weighted_sums = {}

# Iterate through each city name
for city in city_names:
    weighted_sum = (
        weightstemperature_2m_mean[city] *weightsSolar ['Temperature_2m'] + weightsshortwave_radiation_sum[city]* weightsSolar ['Solar_Radiation'] +
        weightset0_fao_evapotranspiration[city]* weightsSolar ['Evaporation'] + highways_max.target_weights[city]*weightsSolar['highways']+
        LULC_max.target_weights[city]*weightsSolar['LULC'] + weightswindspeed_10m_max[city]*weightsSolar ['windspeed_10m']
        
    )
    weighted_sums[city] = weighted_sum


SolarRanking = pd.DataFrame(list(weighted_sums.items()), columns=['City', 'Value'])

# Sort the DataFrame by 'roi' in descending order
sorted_avg_solar = SolarRanking.sort_values(by='Value', ascending=False)

# Print the sorted DataFrame
sorted_avg_solar
# Out:
#     Unnamed: 0             City     Value
# 0            2          Raichur  0.085720
# 1            1            Kolar  0.049515
# 2           21           Mandya  0.046548
# 3           18          Belgaum  0.043129
# 4           10            Bidar  0.041831
# 5           15            Gadag  0.037687
# 6           12           Koppal  0.037405
# 7           16           Haveri  0.034862
# 8           13           Hassan  0.034429
# 9            3  Bangalore Rural  0.034259
# 10          14         Gulbarga  0.034188
# 11          25            Udupi  0.033900
# 12          17           Kodagu  0.033696
# 13           5   Dakshin Kannad  0.033438
# 14          22  Bangalore Urban  0.033391
# 15           8      Chikmagalur  0.033259
# 16           0         Bagalkot  0.033077
# 17          19          Dharwad  0.032621
# 18          24           Tumkur  0.032237
# 19          26    Uttar Kannand  0.032120
# 20          11       Davanagere  0.032057
# 21           9      Chitradurga  0.031996
# 22          23          Shimoga  0.031628
# 23           4          Bellary  0.031464
# 24           6          Bijapur  0.031339
# 25           7     Chamrajnagar  0.031299
# 26          20           Mysore  0.031244
